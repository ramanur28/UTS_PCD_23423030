# %% [markdown]
# <a href="https://colab.research.google.com/github/ramanur28/UTS_PCD_23423030/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Display Original Image and its Histogram
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
hist_original = cv2.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist_original, color='black')
plt.title('Histogram of Original Image')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.xlim([0, 256])
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Display Negative Image and its Histogram
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_negative, cmap='gray')
plt.title('Negative Transformation')
plt.axis('off')

plt.subplot(1, 2, 2)
hist_negative = cv2.calcHist([img_negative], [0], None, [256], [0, 256])
plt.plot(hist_negative, color='black')
plt.title('Histogram of Negative Image')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.xlim([0, 256])
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Display Logarithmic Transformed Image and its Histogram
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_log, cmap='gray')
plt.title('Logarithmic Transformation')
plt.axis('off')

plt.subplot(1, 2, 2)
hist_log = cv2.calcHist([img_log], [0], None, [256], [0, 256])
plt.plot(hist_log, color='black')
plt.title('Histogram of Logarithmic Image')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.xlim([0, 256])
plt.grid(True)

plt.tight_layout()
plt.show()
